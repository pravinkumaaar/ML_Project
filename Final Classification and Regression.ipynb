# %%
import pandas as pd 
import numpy as np
# Creating a dataframe of the merged data

df = pd.read_csv("Final_Merged_Data.csv")
df
# Out:
#          FlightDate  Quarter  Year  Month  DayofMonth Origin Dest  DepTime  \
# 0        2016-01-01        1  2016      1           1    LAX  IAH     1500
# 1        2016-01-01        1  2016      1           1    IAH  DEN     2200
# 2        2016-01-01        1  2016      1           1    SEA  IAH      600
# 3        2016-01-01        1  2016      1           1    ORD  EWR     1300
# 4        2016-01-01        1  2016      1           1    EWR  DEN     1900
# 5        2016-01-01        1  2016      1           1    IAH  EWR     2000
# 6        2016-01-01        1  2016      1           1    DFW  EWR     1300
# 7        2016-01-01        1  2016      1           1    EWR  MIA     1800
# 8        2016-01-01        1  2016      1           1    IAH  SEA     1900
# 9        2016-01-01        1  2016      1           1    MCO  ORD     1800
# 10       2016-01-01        1  2016      1           1    EWR  SFO     2000
# ...

# %%
df.dtypes
# Out:
# FlightDate               object
# Quarter                   int64
# Year                      int64
# Month                     int64
# DayofMonth                int64
# Origin                   object
# Dest                     object
# DepTime                   int64
# DepDel15                float64
# CRSDepTime                int64
# DepDelayMinutes         float64
# OriginAirportID           int64
# DestAirportID             int64
# ArrTime                   int64
# CRSArrTime                int64
# ArrDel15                float64
# ArrDelayMinutes         float64
# date_Origin              object
# time_Origin               int64
# airport_Origin           object
# tempF_Origin              int64
# windspeedKmph_Origin      int64
# winddirDegree_Origin      int64
# weatherCode_Origin        int64
# precipMM_Origin         float64
# humidity_Origin           int64
# visibility_Origin         int64
# pressure_Origin           int64
# cloudcover_Origin         int64
# ...

# %%
pip install numpy
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip install numpy
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more information on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
df.isna().sum()
# Out:
# FlightDate              0
# Quarter                 0
# Year                    0
# Month                   0
# DayofMonth              0
# Origin                  0
# Dest                    0
# DepTime                 0
# DepDel15                0
# CRSDepTime              0
# DepDelayMinutes         0
# OriginAirportID         0
# DestAirportID           0
# ArrTime                 0
# CRSArrTime              0
# ArrDel15                0
# ArrDelayMinutes         0
# date_Origin             0
# time_Origin             0
# airport_Origin          0
# tempF_Origin            0
# windspeedKmph_Origin    0
# winddirDegree_Origin    0
# weatherCode_Origin      0
# precipMM_Origin         0
# humidity_Origin         0
# visibility_Origin       0
# pressure_Origin         0
# cloudcover_Origin       0
# DewPointF_Origin        0
# WindChillF_Origin       0
# WindGustKmph_Origin     0
# date_Dest               0
# time_Dest               0
# airport_Dest            0
# ...

# %%
df["windspeedKmph_Origin"]
# Out:
# 0           5
# 1          12
# 2           7
# 3          23
# 4          19
# 5          14
# 6          17
# 7          20
# 8          15
# 9           8
# 10         18
# 11          4
# 12         25
# 13          7
# 14          6
# 15          4
# 16          9
# 17         20
# 18         18
# 19         23
# 20         18
# 21          8
# 22          7
# 23         17
# 24         10
# 25          5
# 26         14
# 27         12
# 28         16
# 29         18
#            ..
# 1851406     9
# 1851407    18
# 1851408    13
# 1851409    22
# 1851410     7
# 1851411    11
# 1851412    20
# 1851413    11
# 1851414     4
# 1851415    11
# 1851416    13
# 1851417    11
# 1851418     3
# 1851419    14
# 1851420    11
# 1851421     9
# 1851422    18
# 1851423     3
# 1851424     1
# 1851425     9
# 1851426    18
# 1851427    22
# 1851428     2
# 1851429    11
# 1851430    11
# 1851431    18
# 1851432     8
# 1851433    15
# 1851434    11
# 1851435     4
# ...

# %%
df.columns
# Out:
# Index(['FlightDate', 'Quarter', 'Year', 'Month', 'DayofMonth', 'Origin',
#        'Dest', 'DepTime', 'DepDel15', 'CRSDepTime', 'DepDelayMinutes',
#        'OriginAirportID', 'DestAirportID', 'ArrTime', 'CRSArrTime', 'ArrDel15',
#        'ArrDelayMinutes', 'date_Origin', 'time_Origin', 'airport_Origin',
#        'tempF_Origin', 'windspeedKmph_Origin', 'winddirDegree_Origin',
#        'weatherCode_Origin', 'precipMM_Origin', 'humidity_Origin',
#        'visibility_Origin', 'pressure_Origin', 'cloudcover_Origin',
#        'DewPointF_Origin', 'WindChillF_Origin', 'WindGustKmph_Origin',
#        'date_Dest', 'time_Dest', 'airport_Dest', 'tempF_Dest',
#        'windspeedKmph_Dest', 'winddirDegree_Dest', 'weatherCode_Dest',
#        'precipMM_Dest', 'humidity_Dest', 'visibility_Dest', 'pressure_Dest',
#        'cloudcover_Dest', 'DewPointF_Dest', 'WindChillF_Dest',
#        'WindGustKmph_Dest'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# FlightDate              0
# Quarter                 0
# Year                    0
# Month                   0
# DayofMonth              0
# Origin                  0
# Dest                    0
# DepTime                 0
# DepDel15                0
# CRSDepTime              0
# DepDelayMinutes         0
# OriginAirportID         0
# DestAirportID           0
# ArrTime                 0
# CRSArrTime              0
# ArrDel15                0
# ArrDelayMinutes         0
# date_Origin             0
# time_Origin             0
# airport_Origin          0
# tempF_Origin            0
# windspeedKmph_Origin    0
# winddirDegree_Origin    0
# weatherCode_Origin      0
# precipMM_Origin         0
# humidity_Origin         0
# visibility_Origin       0
# pressure_Origin         0
# cloudcover_Origin       0
# DewPointF_Origin        0
# WindChillF_Origin       0
# WindGustKmph_Origin     0
# date_Dest               0
# time_Dest               0
# airport_Dest            0
# ...

# %%
print(df.shape)
# Out:
# (1851436, 47)

# %%
print(df["Origin"].unique())
print(df["Dest"].unique())
# Out:
# ['LAX' 'IAH' 'SEA' 'ORD' 'EWR' 'DFW' 'MCO' 'PHX' 'MIA' 'SFO' 'DEN' 'LAS'
#  'JFK' 'ATL' 'CLT']
# ['IAH' 'DEN' 'EWR' 'MIA' 'SEA' 'ORD' 'SFO' 'MCO' 'ATL' 'LAS' 'LAX' 'JFK'
#  'CLT' 'PHX' 'DFW']

# %%
print(df.groupby("Origin").size())
print(df.groupby("Dest").size())
# Out:
# Origin
# ATL    147065
# CLT     83486
# DEN    144149
# DFW    125904
# EWR    100170
# IAH     89551
# JFK     93437
# LAS    132155
# LAX    209322
# MCO     99568
# MIA     76540
# ORD    153438
# PHX    114012
# SEA    115707
# SFO    166932
# dtype: int64
# Dest
# ATL    147719
# CLT     83434
# DEN    142390
# DFW    125493
# EWR    100456
# IAH     89799
# JFK     93453
# LAS    132400
# LAX    210197
# MCO     99669
# MIA     76651
# ORD    153584
# PHX    113813
# SEA    115838
# SFO    166540
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
#sns.countplot(df["Origin"], label="Count")
ax = df['Origin'].plot(kind='bar')
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-b61d1f4e8f98> in <module>
#       3 import matplotlib.ticker as mtick
#       4 #sns.countplot(df["Origin"], label="Count")
# ----> 5 ax = df['Origin'].plot(kind='bar')
#       6 ax.yaxis.set_major_formatter(mtick.PercentFormatter())
#       7 #plt.show()
#
# ~/.local/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2737                            colormap=colormap, table=table, yerr=yerr,
#    2738                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2739                            **kwds)
#    2740     __call__.__doc__ = plot_series.__doc__
#    2741
#
# ...

# %%
sns.countplot(df["ArrDel15"], label="Count")
plt.show()

# %%
print(len(list(df['ArrDel15'])))
df['ArrDel15'].value_counts()
y=[(1463378/1851436)*100,(388058/1851436)*100]
x=['On-time','Delayed']

ax = sns.barplot(x, y)#, estimator=lambda x: len(x) / len(df) * 100)
ax.set(ylabel="Percent")
# Out:
# 1851436
# [Text(0, 0.5, 'Percent')]

# %%
plt.pie(df['ArrDel15'], labels = {"Count"}, autopct ='% 1.1f %%', shadow = True) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-1de866f44004> in <module>
# ----> 1 plt.pie(df['ArrDel15'], labels = {"Count"}, autopct ='% 1.1f %%', shadow = True)
#       2 plt.show()
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, data)
#    2803         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2804         frame=frame, rotatelabels=rotatelabels, **({"data": data} if
# -> 2805         data is not None else {}))
#    2806
#    2807
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
# ...

# %%
df_ = df["ArrDel15"]
ax = df.plot()
type(ax)  # matplotlib.axes._subplots.AxesSubplot

# manipulate
vals = ax.get_yticks()
ax.set_yticklabels(['{:,.2%}'.format(x) for x in vals])
# Out:
# [Text(0, 0, '-200,000.00%'),
#  Text(0, 0, '0.00%'),
#  Text(0, 0, '200,000.00%'),
#  Text(0, 0, '400,000.00%'),
#  Text(0, 0, '600,000.00%'),
#  Text(0, 0, '800,000.00%'),
#  Text(0, 0, '1,000,000.00%'),
#  Text(0, 0, '1,200,000.00%'),
#  Text(0, 0, '1,400,000.00%'),
#  Text(0, 0, '1,600,000.00%')]

# %%
df.plot(kind='box', subplots=True, layout=(6,7), sharex=False, sharey=False, figsize=(10,10), title=' ')
#plt.savefig('fruits_box')
plt.show()

# %%
# roc curve and auc
from sklearn.datasets import make_classification
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot
# generate 2 class dataset
X, y = make_classification(n_samples=1000, n_classes=2, weights=[1,1], random_state=1)
# split into train/test sets
trainX, testX, trainy, testy = train_test_split(X, y, test_size=0.5, random_state=2)
# fit a model
model = KNeighborsClassifier(n_neighbors=3)
model.fit(trainX, trainy)
# predict probabilities
probs = model.predict_proba(testX)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(testy, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
fpr, tpr, thresholds = roc_curve(testy, probs)
# plot no skill
pyplot.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
pyplot.plot(fpr, tpr, marker='.')
# labeling
plt.ylabel("True positive rate")
plt.xlabel("False positive rate")
# show the plot
pyplot.show()
# Out:
# AUC: 0.895

# %%
#   (0.2112, 'DepDelayMinutes'), (0.2093, 'ArrDelayMinutes'), (0.1085, 'DepDel15'), 
#   (0.0078, 'ArrTime'), (0.0048, 'CRSDepTime'), (0.0041, 'DepTime'), (0.0012, 'precipMM_Origin'), 
#   (0.0007, 'CRSArrTime'), (0.0004, 'visibility_Dest'), (0.0004, 'DewPointF_Origin'), (0.0002, 'weatherCode_Dest'),
#   (0.0002, 'WindGustKmph_Dest'), (0.0001, 'winddirDegree_Origin'), (0.0001, 'winddirDegree_Dest'), 
#   (0.0001, 'weatherCode_Origin'), (0.0001, 'tempF_Origin'), (0.0001, 'tempF_Dest'), (0.0001, 'pressure_Origin'), 
#   (0.0001, 'pressure_Dest'), (0.0001, 'precipMM_Dest'), (0.0001, 'humidity_Origin'), (0.0001, 'humidity_Dest'), 
#   (0.0001, 'WindGustKmph_Origin'), (0.0001, 'WindChillF_Origin'), (0.0001, 'WindChillF_Dest'), (0.0001, 'DewPointF_Dest')
feature_name = []
#feature_name = ['DepTime', 'DepDel15', 'CRSDepTime', 'DepDelayMinutes', 'ArrTime', 'CRSArrTime', 'ArrDel15','ArrDelayMinutes','tempF_Origin', 'windspeedKmph_Origin', 'winddirDegree_Origin','weatherCode_Origin', 'precipMM_Origin', 'humidity_Origin','visibility_Origin', 'pressure_Origin', 'cloudcover_Origin','DewPointF_Origin', 'WindChillF_Origin', 'WindGustKmph_Origin', 'tempF_Dest','windspeedKmph_Dest', 'winddirDegree_Dest', 'weatherCode_Dest', 'precipMM_Dest', 'humidity_Dest', 'visibility_Dest', 'pressure_Dest','cloudcover_Dest', 'DewPointF_Dest', 'WindChillF_Dest','WindGustKmph_Dest']
feature_name = ['tempF_Origin', 'windspeedKmph_Origin', 'winddirDegree_Origin','weatherCode_Origin', 'precipMM_Origin', 'humidity_Origin','visibility_Origin', 'pressure_Origin', 'cloudcover_Origin','DewPointF_Origin', 'WindChillF_Origin', 'WindGustKmph_Origin', 'tempF_Dest','windspeedKmph_Dest', 'winddirDegree_Dest', 'weatherCode_Dest', 'precipMM_Dest', 'humidity_Dest', 'visibility_Dest', 'pressure_Dest','cloudcover_Dest', 'DewPointF_Dest', 'WindChillF_Dest','WindGustKmph_Dest']
x = df[feature_name]
y = df['ArrDel15']
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2,train_size = 0.8)

# %%
feature_name = []
feature_name = ['windspeedKmph_Dest', 'winddirDegree_Dest', 'weatherCode_Dest', 'precipMM_Dest', 'humidity_Dest', 'visibility_Dest', 'cloudcover_Dest','DewPointF_Dest', 'WindChillF_Dest', 'WindGustKmph_Dest']#, 'tempF_Dest', 'windspeedKmph_Dest', 'winddirDegree_Dest','weatherCode_Dest', 'precipMM_Dest', 'humidity_Dest', 'visibility_Dest','pressure_Dest', 'cloudcover_Dest', 'DewPointF_Dest', 'WindChillF_Dest','WindGustKmph_Dest']
#, 'DepartureDelayGroups', 'DepTimeBlk']#, "ArrDelay", "ArrDelayMinutes", "ArrDel15", "ArrivalDelayGroups", "ArrTimeBlk", "CarrierDealy", "WeatherDelay", "NASDelay", "SecurityDelay", "LateAircraftDelay", "DivArrDelay"]
x = df[feature_name]
y = df['ArrDel15']
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2,train_size = 0.8)

# %%
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf = RandomForestClassifier(n_estimators = 100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(x_train,y_train)

from sklearn.metrics import classification_report
pred = clf.predict(x_test)
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.93      0.88    292593
#          1.0       0.53      0.28      0.37     77695
#
#    micro avg       0.80      0.80      0.80    370288
#    macro avg       0.68      0.61      0.62    370288
# weighted avg       0.77      0.80      0.77    370288

# %%
df_depDel = df[df['DepDel15']==1]
#print(df_depDel)
#df_dep_arr_Del = df_depDel[df_depDel['ArrDel15']==0]
print(df_depDel.ArrDel15.value_counts())
#print(df_dep_arr_Del.ArrDel15.value_counts())
# Out:
# 1.0    292550
# 0.0     79529
# Name: ArrDel15, dtype: int64

# %% [markdown]
# # REGRESSION

# %%
df_reg = df[df['ArrDel15']==1]
df_reg.ArrDel15.value_counts()
# Out:
# 1.0    388058
# Name: ArrDel15, dtype: int64

# %%
feature_name = []

#Before the flight leaves Origin

feature_name = ['tempF_Origin', 'windspeedKmph_Origin', 'winddirDegree_Origin','weatherCode_Origin', 'precipMM_Origin', 'humidity_Origin','visibility_Origin', 'pressure_Origin', 'cloudcover_Origin','DewPointF_Origin', 'WindChillF_Origin', 'WindGustKmph_Origin', 'tempF_Dest','windspeedKmph_Dest', 'winddirDegree_Dest', 'weatherCode_Dest', 'precipMM_Dest', 'humidity_Dest', 'visibility_Dest', 'pressure_Dest','cloudcover_Dest', 'DewPointF_Dest', 'WindChillF_Dest','WindGustKmph_Dest']

#After flight leaves Origin and hasn't reached the Destination yet

feature_name1 = ['DepTime', 'DepDel15', 'CRSDepTime', 'DepDelayMinutes', 'time_Origin', 'tempF_Origin', 'windspeedKmph_Origin', 'winddirDegree_Origin','weatherCode_Origin', 'precipMM_Origin', 'humidity_Origin','visibility_Origin', 'pressure_Origin', 'cloudcover_Origin','DewPointF_Origin', 'WindChillF_Origin', 'WindGustKmph_Origin', 'time_Dest', 'tempF_Dest', 'windspeedKmph_Dest', 'winddirDegree_Dest', 'weatherCode_Dest','precipMM_Dest', 'humidity_Dest', 'visibility_Dest', 'pressure_Dest','cloudcover_Dest', 'DewPointF_Dest', 'WindChillF_Dest','WindGustKmph_Dest']

x = df_reg[feature_name]
y = df_reg['ArrDelayMinutes']

X = df_reg[feature_name1]
Y = df_reg['ArrDelayMinutes']

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2,train_size = 0.8)
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.2,train_size = 0.8)

# %%
from sklearn.ensemble import ExtraTreesClassifier

# feature extraction
model = ExtraTreesClassifier()
model.fit(x, y)
print(model.feature_importances_)
# Out:
# /home/praveen/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-d8e186575091> in <module>
#       3 # feature extraction
#       4 model = ExtraTreesClassifier()
# ----> 5 model.fit(x, y)
#       6 print(model.feature_importances_)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     248
#     249         # Validate or convert input data
# --> 250         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     251         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     252         if sample_weight is not None:
#
# ...

# %%
#Linear Regression 

#Before leaving Origin

import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

lm = linear_model.LinearRegression()
model = lm.fit(x_train, y_train)
predictions = lm.predict(x_test)
#predictions[0:5]
#print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("R2 Score : ", r2_score(y_test, predictions))
print("Mean Squared Error : ", mean_squared_error(y_test, predictions))
print("Root Mean Squared Error : ", mean_squared_error(y_test, predictions)**0.5)
print("Mean Absolute Error : ", mean_absolute_error(y_test, predictions))
# Out:
# R2 Score :  0.020859257659824992
# Mean Squared Error :  5139.419509664424
# Root Mean Squared Error :  71.68974480122262
# Mean Absolute Error :  42.4792743731784

# %%
#Linear Regression

#Midway after leaving Origin

import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

lm = linear_model.LinearRegression()
model = lm.fit(X_train, Y_train)
predictions = lm.predict(X_test)
#predictions[0:5]
#print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("R2 Score : ", r2_score(Y_test, predictions))
print("Mean Squared Error : ", mean_squared_error(Y_test, predictions))
print("Root Mean Squared Error : ", mean_squared_error(Y_test, predictions)**0.5)
print("Mean Absolute Error : ", mean_absolute_error(Y_test, predictions))
# Out:
# R2 Score :  0.9402244229352604
# Mean Squared Error :  305.7098319409537
# Root Mean Squared Error :  17.484559815475873
# Mean Absolute Error :  12.13670538782994

# %%
#Extra Trees Regressor

#Before leaving Origin

import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

model = ExtraTreesRegressor(n_estimators=40)
model = model.fit(x_train, y_train)
predictions = model.predict(x_test)

print("R2 Score : ", r2_score(y_test, predictions))
print("Mean Squared Error : ", mean_squared_error(y_test, predictions))
print("Root Mean Squared Error : ", mean_squared_error(y_test, predictions)**0.5)
print("Mean Absolute Error : ", mean_absolute_error(y_test, predictions))
# Out:
# R2 Score :  -0.08218027854551835
# Mean Squared Error :  5756.5182544666295
# Root Mean Squared Error :  75.87172236391257
# Mean Absolute Error :  44.92456307765982

# %%
#Extra Trees Regressor

#Midway after leaving Origin

#Best results for the case where the delay is predicted after the flight leaves the origin

import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

model = ExtraTreesRegressor(n_estimators=40)
model = model.fit(X_train, Y_train)
predictions = model.predict(X_test)

print("R2 Score : ", r2_score(Y_test, predictions))
print("Mean Squared Error : ", mean_squared_error(Y_test, predictions))
print("Root Mean Squared Error : ", mean_squared_error(Y_test, predictions)**0.5)
print("Mean Absolute Error : ", mean_absolute_error(Y_test, predictions))
# Out:
# R2 Score :  0.9463549790224736
# Mean Squared Error :  274.3563701567752
# Root Mean Squared Error :  16.5637064136254
# Mean Absolute Error :  11.702832626827465

# %%
#XGB Regressor

#Before leaving Origin

#Best results for the case where the delay is predicted before the flight leaves the origin

from numpy import loadtxt
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

xg_reg = xgb.XGBRegressor()
model = xg_reg.fit(x_train, y_train)
predictions = model.predict(x_test)

print("R2 Score : ", r2_score(y_test, predictions))
print("Mean Squared Error : ", mean_squared_error(y_test, predictions))
print("Root Mean Squared Error : ", mean_squared_error(y_test, predictions)**0.5)
print("Mean Absolute Error : ", mean_absolute_error(y_test, predictions))
# Out:
# R2 Score :  0.028795368808172683
# Mean Squared Error :  4993.471305618906
# Root Mean Squared Error :  70.66449819830963
# Mean Absolute Error :  42.17604555870118

# %%
#XGB Regressor

#Midway after leaving Origin

#Best results for the case where the delay is predicted after the flight leaves the origin

from numpy import loadtxt
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

xg_reg = xgb.XGBRegressor()
model = xg_reg.fit(X_train, Y_train)
predictions = model.predict(X_test)

print("R2 Score : ", r2_score(Y_test, predictions))
print("Mean Squared Error : ", mean_squared_error(Y_test, predictions))
print("Root Mean Squared Error : ", mean_squared_error(Y_test, predictions)**0.5)
print("Mean Absolute Error : ", mean_absolute_error(Y_test, predictions))
# Out:
# R2 Score :  0.9451788005221526
# Mean Squared Error :  280.37169195410814
# Root Mean Squared Error :  16.744303268697333
# Mean Absolute Error :  11.600593483215176

# %%
from sklearn import svm

reg = svm.SVR()
model = reg.fit(x_train, y_train)
predictions = reg.predict(x_test)

print("R2 Score : ", r2_score(y_test, predictions))
print("Mean Squared Error : ", mean_squared_error(y_test, predictions))
# Out:
# /home/praveen/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
plt.scatter(y_test, predictions)
plt.xlabel('True Values')
plt.ylabel('Predictions')
# Out:
# Text(0, 0.5, 'Predictions')

# %%
# Out:
# 0.020241313284990903

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x_train, y_train)
print('Accuracy of GNB classifier on training set: {:.2f}'.format(gnb.score(x_train, y_train)))
print('Accuracy of GNB classifier on test set: {:.2f}'.format(gnb.score(x_test, y_test)))
# Out:
# Accuracy of GNB classifier on training set: 0.75
# Accuracy of GNB classifier on test set: 0.75

# %%
from sklearn.metrics import classification_report
pred = clf.predict(x_test)
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.95      0.88    292838
#          1.0       0.56      0.26      0.35     77450
#
#    micro avg       0.80      0.80      0.80    370288
#    macro avg       0.69      0.60      0.62    370288
# weighted avg       0.77      0.80      0.77    370288

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(x_train, y_train)
print('Accuracy of Logistic regression classifier on training set: {:.2f}'.format(logreg.score(x_train, y_train)))
print('Accuracy of Logistic regression classifier on test set: {:.2f}'.format(logreg.score(x_test, y_test)))
# Out:
# /home/praveen/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Accuracy of Logistic regression classifier on training set: 0.79
# Accuracy of Logistic regression classifier on test set: 0.79

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier().fit(x_train, y_train)
print('Accuracy of Decision Tree classifier on training set: {:.2f}'.format(clf.score(x_train, y_train)))
print('Accuracy of Decision Tree classifier on test set: {:.2f}'.format(clf.score(x_test, y_test)))
# Out:
# Accuracy of Decision Tree classifier on training set: 0.97
# Accuracy of Decision Tree classifier on test set: 0.73

# %%
from sklearn.metrics import classification_report
pred = clf.predict(x_test)
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.83      0.83    293001
#          1.0       0.35      0.35      0.35     77287
#
#    micro avg       0.73      0.73      0.73    370288
#    macro avg       0.59      0.59      0.59    370288
# weighted avg       0.73      0.73      0.73    370288

# %%
import numpy as np
print(np.unique(pred))

#Check the metrics involved
# Out:
# [0. 1.]

# %%
df[df.ArrDel15 == 0]
# Out:
#          FlightDate  Quarter  Year  Month  DayofMonth Origin Dest  DepTime  \
# 1        2016-01-01        1  2016      1           1    IAH  DEN     2200
# 2        2016-01-01        1  2016      1           1    SEA  IAH      600
# 3        2016-01-01        1  2016      1           1    ORD  EWR     1300
# 4        2016-01-01        1  2016      1           1    EWR  DEN     1900
# 5        2016-01-01        1  2016      1           1    IAH  EWR     2000
# 6        2016-01-01        1  2016      1           1    DFW  EWR     1300
# 7        2016-01-01        1  2016      1           1    EWR  MIA     1800
# 8        2016-01-01        1  2016      1           1    IAH  SEA     1900
# 9        2016-01-01        1  2016      1           1    MCO  ORD     1800
# 10       2016-01-01        1  2016      1           1    EWR  SFO     2000
# 11       2016-01-01        1  2016      1           1    MCO  ORD      900
# ...

# %%
df[df.ArrDel15 == 1]
# Out:
#          FlightDate  Quarter  Year  Month  DayofMonth Origin Dest  DepTime  \
# 0        2016-01-01        1  2016      1           1    LAX  IAH     1500
# 12       2016-01-01        1  2016      1           1    ORD  EWR     1800
# 23       2016-01-01        1  2016      1           1    IAH  ORD      100
# 24       2016-01-01        1  2016      1           1    MIA  DEN      900
# 31       2016-01-01        1  2016      1           1    LAX  DEN     1200
# 36       2016-01-01        1  2016      1           1    LAX  LAS     1300
# 56       2016-01-01        1  2016      1           1    LAX  ORD     1900
# 61       2016-01-01        1  2016      1           1    DFW  LAX      100
# 62       2016-01-01        1  2016      1           1    ATL  LAX     1200
# 64       2016-01-01        1  2016      1           1    DEN  IAH     1700
# 80       2016-01-01        1  2016      1           1    DEN  PHX     1300
# ...

# %%
from imblearn.over_sampling import SMOTE
print("Before OverSampling, counts of label '1': {}".format(sum(y_train==1)))
print("Before OverSampling, counts of label '0': {} \n".format(sum(y_train==0)))

sm = SMOTE(random_state=2)
x_train_res, y_train_res = sm.fit_sample(x_train, y_train.ravel())

print('After OverSampling, the shape of train_X: {}'.format(x_train_res.shape))
print('After OverSampling, the shape of train_y: {} \n'.format(y_train_res.shape))

print("After OverSampling, counts of label '1': {}".format(sum(y_train_res==1)))
print("After OverSampling, counts of label '0': {}".format(sum(y_train_res==0)))
# Out:
# Before OverSampling, counts of label '1': 310608
# Before OverSampling, counts of label '0': 1170540
#
# After OverSampling, the shape of train_X: (2341080, 10)
# After OverSampling, the shape of train_y: (2341080,)
#
# After OverSampling, counts of label '1': 1170540
# After OverSampling, counts of label '0': 1170540

# %% [markdown]
# # UNDER SAMPLING

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd

df_majority = df[df.ArrDel15 == 0]
df_minority = df[df.ArrDel15 == 1]
 
df_majority = df_majority.sample(n = 388058, random_state = 1)
#df_minority
list_df = [df_majority, df_minority]
df_new = pd.concat(list_df)
df_new.ArrDel15.value_counts()
# Out:
# 1.0    388058
# 0.0    388058
# Name: ArrDel15, dtype: int64

# %%
feature_name = []
feature_name = ['tempF_Dest', 'windspeedKmph_Dest', 'winddirDegree_Dest', 'weatherCode_Dest', 'precipMM_Dest', 'humidity_Dest', 'visibility_Dest', 'pressure_Dest', 'cloudcover_Dest','DewPointF_Dest', 'WindChillF_Dest', 'WindGustKmph_Dest']#, 'tempF_Dest', 'windspeedKmph_Dest', 'winddirDegree_Dest','weatherCode_Dest', 'precipMM_Dest', 'humidity_Dest', 'visibility_Dest','pressure_Dest', 'cloudcover_Dest', 'DewPointF_Dest', 'WindChillF_Dest','WindGustKmph_Dest']
#, 'DepartureDelayGroups', 'DepTimeBlk']#, "ArrDelay", "ArrDelayMinutes", "ArrDel15", "ArrivalDelayGroups", "ArrTimeBlk", "CarrierDealy", "WeatherDelay", "NASDelay", "SecurityDelay", "LateAircraftDelay", "DivArrDelay"]
x = df_new[feature_name]
y = df_new['ArrDel15']
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-275954cbff7b> in <module>
#       2 feature_name = ['tempF_Dest', 'windspeedKmph_Dest', 'winddirDegree_Dest', 'weatherCode_Dest', 'precipMM_Dest', 'humidity_Dest', 'visibility_Dest', 'pressure_Dest', 'cloudcover_Dest','DewPointF_Dest', 'WindChillF_Dest', 'WindGustKmph_Dest']#, 'tempF_Dest', 'windspeedKmph_Dest', 'winddirDegree_Dest','weatherCode_Dest', 'precipMM_Dest', 'humidity_Dest', 'visibility_Dest','pressure_Dest', 'cloudcover_Dest', 'DewPointF_Dest', 'WindChillF_Dest','WindGustKmph_Dest']
#       3 #, 'DepartureDelayGroups', 'DepTimeBlk']#, "ArrDelay", "ArrDelayMinutes", "ArrDel15", "ArrivalDelayGroups", "ArrTimeBlk", "CarrierDealy", "WeatherDelay", "NASDelay", "SecurityDelay", "LateAircraftDelay", "DivArrDelay"]
# ----> 4 x = df_new[feature_name]
#       5 y = df_new['ArrDel15']
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2,train_size = 0.8)

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier().fit(x_train, y_train)
print('Accuracy of Decision Tree classifier on training set: {:.2f}'.format(clf.score(x_train, y_train)))
print('Accuracy of Decision Tree classifier on test set: {:.2f}'.format(clf.score(x_test, y_test)))
# Out:
# Accuracy of Decision Tree classifier on training set: 0.79
# Accuracy of Decision Tree classifier on test set: 0.63

# %%
# Random Forest Classifier

from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf = RandomForestClassifier(n_estimators = 100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(x_train,y_train)

y_pred = clf.predict(x_test)

# %%
from sklearn.metrics import classification_report
pred=clf.predict(x_test)
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.64      0.63     77437
#          1.0       0.64      0.63      0.64     77787
#
#    micro avg       0.63      0.63      0.63    155224
#    macro avg       0.63      0.63      0.63    155224
# weighted avg       0.63      0.63      0.63    155224

# %%
df[df.ArrDel15 == 0]
# Out:
#          FlightDate  Quarter  Year  Month  DayofMonth Origin Dest  DepTime  \
# 1        2016-01-01        1  2016      1           1    IAH  DEN     2200
# 2        2016-01-01        1  2016      1           1    SEA  IAH      600
# 3        2016-01-01        1  2016      1           1    ORD  EWR     1300
# 4        2016-01-01        1  2016      1           1    EWR  DEN     1900
# 5        2016-01-01        1  2016      1           1    IAH  EWR     2000
# 6        2016-01-01        1  2016      1           1    DFW  EWR     1300
# 7        2016-01-01        1  2016      1           1    EWR  MIA     1800
# 8        2016-01-01        1  2016      1           1    IAH  SEA     1900
# 9        2016-01-01        1  2016      1           1    MCO  ORD     1800
# 10       2016-01-01        1  2016      1           1    EWR  SFO     2000
# 11       2016-01-01        1  2016      1           1    MCO  ORD      900
# ...

# %% [markdown]
# # OVER SAMPLING

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd

df_majority = df[df.ArrDel15 == 0]
df_minority = df[df.ArrDel15 == 1]
print(len(df_majority),len(df_minority))
df_minority = df_minority.sample(n = 1463378, replace = True, random_state = 1)
#df_minority
list_df = [df_majority, df_minority]
df_new = pd.concat(list_df)
df_new.ArrDel15.value_counts()
# Out:
# 1463378 388058
# 1.0    1463378
# 0.0    1463378
# Name: ArrDel15, dtype: int64

# %%
df_minority_add = pd.DataFrame()
df_majority = df[df.ArrDel15 == 0]
df_minority = df[df.ArrDel15 == 1]
print(len(df_majority),len(df_minority))
df_minority_add = df_minority.sample(n = 1075320, replace = True, random_state = 1)
list_minority = [df_minority, df_minority_add]
df_minority = pd.concat(list_minority)
list_df = [df_majority, df_minority]
df_new = pd.concat(list_df)
df_new.ArrDel15.value_counts()
# Out:
# 1463378 388058
# 1.0    1463378
# 0.0    1463378
# Name: ArrDel15, dtype: int64

# %%
df_new.to_csv('RandomOverSampled_dataframe_update.csv', index = False, encoding = 'utf-8')
df_new
# Out:
#          FlightDate  Quarter  Year  Month  DayofMonth Origin Dest  DepTime  \
# 1        2016-01-01        1  2016      1           1    IAH  DEN     2200
# 2        2016-01-01        1  2016      1           1    SEA  IAH      600
# 3        2016-01-01        1  2016      1           1    ORD  EWR     1300
# 4        2016-01-01        1  2016      1           1    EWR  DEN     1900
# 5        2016-01-01        1  2016      1           1    IAH  EWR     2000
# 6        2016-01-01        1  2016      1           1    DFW  EWR     1300
# 7        2016-01-01        1  2016      1           1    EWR  MIA     1800
# 8        2016-01-01        1  2016      1           1    IAH  SEA     1900
# 9        2016-01-01        1  2016      1           1    MCO  ORD     1800
# 10       2016-01-01        1  2016      1           1    EWR  SFO     2000
# 11       2016-01-01        1  2016      1           1    MCO  ORD      900
# ...

# %%
import pandas as pd
df_new = pd.read_csv('RandomOverSampled_dataframe.csv')

# %%
print(df_minority.shape)
print(df_majority.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-cdcf5196ae0f> in <module>
# ----> 1 print(df_minority.shape)
#       2 print(df_majority.shape)
#
# NameError: name 'df_minority' is not defined

# %%
feature_name = []
feature_name = ['windspeedKmph_Dest', 'winddirDegree_Dest', 'weatherCode_Dest', 'precipMM_Dest', 'humidity_Dest', 'visibility_Dest', 'cloudcover_Dest','DewPointF_Dest', 'WindChillF_Dest', 'WindGustKmph_Dest']#, 'tempF_Dest', 'windspeedKmph_Dest', 'winddirDegree_Dest','weatherCode_Dest', 'precipMM_Dest', 'humidity_Dest', 'visibility_Dest','pressure_Dest', 'cloudcover_Dest', 'DewPointF_Dest', 'WindChillF_Dest','WindGustKmph_Dest']
#, 'DepartureDelayGroups', 'DepTimeBlk']#, "ArrDelay", "ArrDelayMinutes", "ArrDel15", "ArrivalDelayGroups", "ArrTimeBlk", "CarrierDealy", "WeatherDelay", "NASDelay", "SecurityDelay", "LateAircraftDelay", "DivArrDelay"]
x = df_new[feature_name]
y = df_new['ArrDel15']
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2,train_size = 0.8)

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier().fit(x_train, y_train)
print('Accuracy of Decision Tree classifier on training set: {:.2f}'.format(clf.score(x_train, y_train)))
print('Accuracy of Decision Tree classifier on test set: {:.2f}'.format(clf.score(x_test, y_test)))
# Out:
# Accuracy of Decision Tree classifier on training set: 0.97
# Accuracy of Decision Tree classifier on test set: 0.73

# %%
from sklearn.metrics import classification_report
pred = clf.predict(x_test)
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.83      0.83    292576
#          1.0       0.36      0.35      0.36     77712
#
#    micro avg       0.73      0.73      0.73    370288
#    macro avg       0.59      0.59      0.59    370288
# weighted avg       0.73      0.73      0.73    370288

# %%
import os  
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns  
from random import sample  
from sklearn.linear_model import LogisticRegression  
from sklearn import tree  
from sklearn.ensemble import RandomForestClassifier  
from sklearn.svm import SVC  
from sklearn.neighbors import KNeighborsClassifier  
from sklearn.naive_bayes import GaussianNB  
# from sklearn.cross_validation import cross_val_score  
from sklearn import metrics  
from IPython.display import Image  
# from pydotplus import graph_from_dot_data

# %%
df = pd.read_csv("Final_Merged_Data.csv")
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cb5cfc6a0ee6> in <module>
# ----> 1 df = pd.read_csv("Final_Merged_Data.csv")
#       2 df.shape
#
# NameError: name 'pd' is not defined

# %%
df.columns.tolist()
# Out:
# ['FlightDate',
#  'Quarter',
#  'Year',
#  'Month',
#  'DayofMonth',
#  'Origin',
#  'Dest',
#  'DepTime',
#  'DepDel15',
#  'CRSDepTime',
#  'DepDelayMinutes',
#  'OriginAirportID',
#  'DestAirportID',
#  'ArrTime',
#  'CRSArrTime',
#  'ArrDel15',
#  'ArrDelayMinutes',
#  'date_Origin',
#  'time_Origin',
#  'airport_Origin',
#  'tempF_Origin',
#  'windspeedKmph_Origin',
#  'winddirDegree_Origin',
#  'weatherCode_Origin',
#  'precipMM_Origin',
#  'humidity_Origin',
#  'visibility_Origin',
#  'pressure_Origin',
#  'cloudcover_Origin',
#  'DewPointF_Origin',
#  'WindChillF_Origin',
#  'WindGustKmph_Origin',
#  'date_Dest',
#  'time_Dest',
#  'airport_Dest',
#  'tempF_Dest',
#  'windspeedKmph_Dest',
#  'winddirDegree_Dest',
#  'weatherCode_Dest',
#  'precipMM_Dest',
#  'humidity_Dest',
#  'visibility_Dest',
#  'pressure_Dest',
#  'cloudcover_Dest',
#  'DewPointF_Dest',
#  'WindChillF_Dest',
#  'WindGustKmph_Dest']

# %%
print '# Delayed Flights = {}'.format(len(df[df['ArrDel15'] == 1]))  
print '# Flights on time = {}'.format(len(df[df['ArrDel15'] == 0]))  
print 'Delayed Flights = {}'.format(round(float(len(df[df['ArrDel15'] == 1])) / len(df) * 100), 3)
# Out:
#   File "<ipython-input-7-73b9d04d2d56>", line 1
#     print '# Delayed Flights = {}'.format(len(df[df['ArrDel15'] == 1]))
#                                  ^
# SyntaxError: invalid syntax

# %%
correlation = df.corr()
plt.figure(figsize=(47, 47))
sns.heatmap(correlation, vmax=1, square=True, annot=True, cmap='cubehelix')

# %%
rf = RandomForestClassifier()
rf.fit(x_train, y_train)
print("Features sorted by their score:")
print(sorted(zip(map(lambda x: round(x, 4), rf.feature_importances_), x_train), reverse=True))
# Out:
# /home/praveen/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Features sorted by their score:
# ...

# %%
df_new.describe()
# Out:
#             Quarter          Year         Month    DayofMonth       DepTime  \
# count  2.926756e+06  2.926756e+06  2.926756e+06  2.926756e+06  2.926756e+06
# mean   2.497578e+00  2.016497e+03  6.488695e+00  1.572315e+01  1.381052e+03
# std    1.088583e+00  4.999928e-01  3.350753e+00  8.770395e+00  5.432307e+02
# min    1.000000e+00  2.016000e+03  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    2.000000e+00  2.016000e+03  4.000000e+00  8.000000e+00  1.000000e+03
# 50%    3.000000e+00  2.016000e+03  7.000000e+00  1.600000e+01  1.400000e+03
# 75%    3.000000e+00  2.017000e+03  9.000000e+00  2.300000e+01  1.800000e+03
# max    4.000000e+00  2.017000e+03  1.200000e+01  3.100000e+01  2.300000e+03
#
#            DepDel15    CRSDepTime  DepDelayMinutes  OriginAirportID  \
# count  2.926756e+06  2.926756e+06     2.926756e+06     2.926756e+06
# mean   4.042093e-01  1.374024e+03     3.021143e+01     1.275468e+04
# std    4.907384e-01  5.034422e+02     5.998633e+01     1.347493e+03
# ...

# %%
# Random Forest Classifier

from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf = RandomForestClassifier(n_estimators = 20)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(x_train,y_train)

y_pred = clf.predict(x_test)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7199206631223606

# %%
from sklearn.metrics import classification_report
pred = clf.predict(x_test)
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.68      0.71    292845
#          1.0       0.70      0.76      0.73    292507
#
#    micro avg       0.72      0.72      0.72    585352
#    macro avg       0.72      0.72      0.72    585352
# weighted avg       0.72      0.72      0.72    585352

# %%
# !pip install imblearn
# Out:
# ...
#     100% |████████████████████████████████| 174kB 1.7MB/s ta 0:00:01
# ...

# %% [markdown]
# # SMOTE OVERSAMPLING

# %%
from imblearn.over_sampling import SMOTE

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

print("Number transactions X_train dataset: ", x_train.shape)
print("Number transactions y_train dataset: ", y_train.shape)
print("Number transactions X_test dataset: ", x_test.shape)
print("Number transactions y_test dataset: ", y_test.shape)
# Out:
# Number transactions X_train dataset:  (1481148, 10)
# Number transactions y_train dataset:  (1481148,)
# Number transactions X_test dataset:  (370288, 10)
# Number transactions y_test dataset:  (370288,)

# %%
print("Before OverSampling, counts of label '1': {}".format(sum(y_train==1)))
print("Before OverSampling, counts of label '0': {} \n".format(sum(y_train==0)))

sm = SMOTE(random_state=2)
x_train_res, y_train_res = sm.fit_sample(x_train, y_train.ravel())
x_test_res, y_test_res = sm.fit_sample(x_test, y_test.ravel())

print('After OverSampling, the shape of train_X: {}'.format(x_train_res.shape))
print('After OverSampling, the shape of train_y: {} \n'.format(y_train_res.shape))

print("After OverSampling, counts of label '1' y_train: {}".format(sum(y_train_res==1)))
print("After OverSampling, counts of label '0' y_train: {}".format(sum(y_train_res==0)))

print("After OverSampling, counts of label '1' y_test: {}".format(sum(y_test_res==1)))
print("After OverSampling, counts of label '0' y_test: {}".format(sum(y_test_res==0)))

# print("After OverSampling, counts of label '1': {}".format(sum(x_train_res==1)))
# print("After OverSampling, counts of label '0': {}".format(sum(x_train_res==0)))

# print("After OverSampling, counts of label '1': {}".format(sum(x_test_res==1)))
# print("After OverSampling, counts of label '0': {}".format(sum(x_test_res==0)))
# Out:
# Before OverSampling, counts of label '1': 310592
# Before OverSampling, counts of label '0': 1170556
#
# After OverSampling, the shape of train_X: (2341112, 10)
# After OverSampling, the shape of train_y: (2341112,)
#
# After OverSampling, counts of label '1' y_train: 1170556
# After OverSampling, counts of label '0' y_train: 1170556
# After OverSampling, counts of label '1' y_test: 292822
# After OverSampling, counts of label '0' y_test: 292822

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier().fit(x_train_res, y_train_res)
print('Accuracy of Decision Tree classifier on training set: {:.2f}'.format(clf.score(x_train_res, y_train_res)))
print('Accuracy of Decision Tree classifier on test set: {:.2f}'.format(clf.score(x_test_res, y_test_res)))
# Out:
# Accuracy of Decision Tree classifier on training set: 0.86
# Accuracy of Decision Tree classifier on test set: 0.80

# %%
from sklearn.metrics import classification_report
pred = clf.predict(x_test_res)
print(classification_report(y_test_res,pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.85      0.81    292822
#          1.0       0.83      0.75      0.79    292822
#
#    micro avg       0.80      0.80      0.80    585644
#    macro avg       0.80      0.80      0.80    585644
# weighted avg       0.80      0.80      0.80    585644

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot

probs = clf.predict_proba(x_test_res)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_test_res, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
fpr, tpr, thresholds = roc_curve(y_test_res, probs)
# plot no skill
pyplot.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
pyplot.plot(fpr, tpr, marker='.')
#labeling 
plt.ylabel("True Positive Rate")
plt.xlabel("False Positive Rate")
# show the plot
pyplot.show()
# Out:
# AUC: 0.864

# %%
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf = RandomForestClassifier(n_estimators = 100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(x_train_res,y_train_res)

y_pred = clf.predict(x_test_res)

# %%
from sklearn.metrics import classification_report
pred = clf.predict(x_test_res)
print(classification_report(y_test_res,pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.84      0.82    292822
#          1.0       0.83      0.78      0.81    292822
#
#    micro avg       0.81      0.81      0.81    585644
#    macro avg       0.81      0.81      0.81    585644
# weighted avg       0.81      0.81      0.81    585644

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot

probs = clf.predict_proba(x_test_res)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_test_res, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
fpr, tpr, thresholds = roc_curve(y_test_res, probs)
# plot no skill
pyplot.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
pyplot.plot(fpr, tpr, marker='.')
# labeling
plt.ylabel("True Positive Rate")
plt.xlabel("False Positive Rate")
# show the plot
pyplot.show()
# Out:
# AUC: 0.877

# %%
from sklearn import model_selection
from sklearn.ensemble import ExtraTreesClassifier

clf = ExtraTreesClassifier(n_estimators = 30)
clf.fit(x_train_res, y_train_res)

y_pred = clf.predict(x_test_res)

# %%
from sklearn.metrics import classification_report
pred = clf.predict(x_test_res)
print(classification_report(y_test_res,pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.85      0.81    292822
#          1.0       0.83      0.74      0.79    292822
#
#    micro avg       0.80      0.80      0.80    585644
#    macro avg       0.80      0.80      0.80    585644
# weighted avg       0.80      0.80      0.80    585644

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot

probs = clf.predict_proba(x_test_res)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_test_res, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
fpr, tpr, thresholds = roc_curve(y_test_res, probs)
# plot no skill
pyplot.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
pyplot.plot(fpr, tpr, marker='.')
# labeling
plt.ylabel("True Positive Rate")
plt.xlabel("False Positive Rate")
# show the plot
pyplot.show()
# Out:
# AUC: 0.857

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot

probs = clf.predict_proba(x_test_res)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_test_res, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
fpr, tpr, thresholds = roc_curve(y_test_res, probs)
# plot no skill
pyplot.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
pyplot.plot(fpr, tpr, marker='.')
# labeling
plt.ylabel("True Positive Rate")
plt.xlabel("False Positive Rate")
# show the plot
pyplot.show()

# %%
from sklearn import model_selection
from sklearn.ensemble import AdaBoostClassifier

model = AdaBoostClassifier(n_estimators = 40)
model.fit(x_train_res, y_train_res)

# %%
from sklearn.metrics import classification_report
pred = model.predict(x_test_res)
print(classification_report(y_test_res,pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.64      0.62    292822
#          1.0       0.62      0.59      0.60    292822
#
#    micro avg       0.61      0.61      0.61    585644
#    macro avg       0.61      0.61      0.61    585644
# weighted avg       0.61      0.61      0.61    585644

# %%
from sklearn import model_selection
from sklearn.ensemble import GradientBoostingClassifier

model = GradientBoostingClassifier(n_estimators = 40)
model.fit(x_train_res, y_train_res)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=40,
#               n_iter_no_change=None, presort='auto', random_state=None,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)

# %%
from sklearn.metrics import classification_report
pred = model.predict(x_test_res)
print(classification_report(y_test_res,pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.72      0.69    292822
#          1.0       0.70      0.64      0.67    292822
#
#    micro avg       0.68      0.68      0.68    585644
#    macro avg       0.68      0.68      0.68    585644
# weighted avg       0.68      0.68      0.68    585644

# %%
from sklearn import model_selection
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

model = XGBClassifier()
model.fit(X_train, y_train)

# %%
from sklearn.metrics import classification_report
pred = model.predict(x_test_res)
print(classification_report(y_test_res,pred))

# %% [markdown]
# # REGRESSION

# %%
from sklearn import metrics

rf = RandomForestClassifier()  
rf_model = rf.fit(x_train, y_train)  
rf_model.score(x_train, y_train)
predicted = pd.DataFrame(rf_model.predict(x_test))  
probs = pd.DataFrame(rf_model.predict_proba(x_test))

rf_accuracy = metrics.accuracy_score(y_test, predicted)  
rf_roc_auc = metrics.roc_auc_score(y_test, probs[1])  
rf_confus_matrix = metrics.confusion_matrix(y_test, predicted)  
rf_classification_report = metrics.classification_report(y_test, predicted)  
rf_precision = metrics.precision_score(y_test, predicted, pos_label=1)  
rf_recall = metrics.recall_score(y_test, predicted, pos_label=1)  
rf_f1 = metrics.f1_score(y_test, predicted, pos_label=1)

rf_cv_scores = cross_val_score(RandomForestClassifier(), x_test, y_test, scoring='precision', cv=47)  
rf_cv_mean = np.mean(rf_cv_scores)
# Out:
# /home/praveen/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-ce0201ea8043> in <module>
#      15 rf_f1 = metrics.f1_score(y_test, predicted, pos_label=1)
#      16
# ---> 17 rf_cv_scores = cross_val_score(RandomForestClassifier(), x_test, y_test, scoring='precision', cv=47)
#      18 rf_cv_mean = np.mean(rf_cv_scores)
#
# NameError: name 'cross_val_score' is not defined

# %%
df.dtypes
# Out:
# FlightDate               object
# Quarter                   int64
# Year                      int64
# Month                     int64
# DayofMonth                int64
# Origin                   object
# Dest                     object
# DepTime                   int64
# DepDel15                float64
# CRSDepTime                int64
# DepDelayMinutes         float64
# OriginAirportID           int64
# DestAirportID             int64
# ArrTime                   int64
# CRSArrTime                int64
# ArrDel15                float64
# ArrDelayMinutes         float64
# date_Origin              object
# time_Origin               int64
# airport_Origin           object
# tempF_Origin              int64
# windspeedKmph_Origin      int64
# winddirDegree_Origin      int64
# weatherCode_Origin        int64
# precipMM_Origin         float64
# humidity_Origin           int64
# visibility_Origin         int64
# pressure_Origin           int64
# cloudcover_Origin         int64
# ...

# %%
y_test
# Out:
# 1036104    0.0
# 923028     0.0
# 818705     0.0
# 1179022    0.0
# 884534     0.0
# 1401558    0.0
# 1453165    0.0
# 689756     0.0
# 793070     0.0
# 891719     1.0
# 665148     1.0
# 554103     1.0
# 135759     1.0
# 1357311    0.0
# 1503665    0.0
# 1774164    0.0
# 762475     0.0
# 1676606    0.0
# 170096     0.0
# 1758650    0.0
# 1258771    0.0
# 100884     0.0
# 180717     0.0
# 1712897    0.0
# 409423     0.0
# 1469072    0.0
# 1528655    0.0
# 88034      0.0
# 1436381    0.0
# 1662019    0.0
#           ...
# 840857     1.0
# 1209778    0.0
# 934738     0.0
# 1500541    1.0
# 331287     0.0
# 1793434    0.0
# 1037146    0.0
# 1773587    0.0
# 1687638    0.0
# 1425624    0.0
# 1003682    0.0
# 1428125    0.0
# 714190     0.0
# 500366     0.0
# 795370     0.0
# 509791     0.0
# 533459     0.0
# 248150     0.0
# 1245838    0.0
# 138973     0.0
# 368850     0.0
# 1183045    0.0
# 1806911    0.0
# 558506     1.0
# 723857     1.0
# 763619     0.0
# 1534791    0.0
# ...

# %%
predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-2ad865615242> in <module>
# ----> 1 predict(x_test)
#
# NameError: name 'predict' is not defined

# %%
df[df.DepDel15 == 1]
# Out:
#          FlightDate  Quarter  Year  Month  DayofMonth Origin Dest  DepTime  \
# 0        2016-01-01        1  2016      1           1    LAX  IAH     1500
# 4        2016-01-01        1  2016      1           1    EWR  DEN     1900
# 8        2016-01-01        1  2016      1           1    IAH  SEA     1900
# 10       2016-01-01        1  2016      1           1    EWR  SFO     2000
# 12       2016-01-01        1  2016      1           1    ORD  EWR     1800
# 15       2016-01-01        1  2016      1           1    LAX  IAH     1600
# 18       2016-01-01        1  2016      1           1    EWR  SFO     1400
# 23       2016-01-01        1  2016      1           1    IAH  ORD      100
# 24       2016-01-01        1  2016      1           1    MIA  DEN      900
# 29       2016-01-01        1  2016      1           1    EWR  IAH     2000
# 31       2016-01-01        1  2016      1           1    LAX  DEN     1200
# ...

# %%
df.keys()
# Out:
# Index(['FlightDate', 'Quarter', 'Year', 'Month', 'DayofMonth', 'Origin',
#        'Dest', 'DepTime', 'DepDel15', 'CRSDepTime', 'DepDelayMinutes',
#        'OriginAirportID', 'DestAirportID', 'ArrTime', 'CRSArrTime', 'ArrDel15',
#        'ArrDelayMinutes', 'date_x', 'time_x', 'airport_x', 'tempF_x',
#        'windspeedKmph_x', 'winddirDegree_x', 'weatherCode_x', 'precipMM_x',
#        'humidity_x', 'visibility_x', 'pressure_x', 'cloudcover_x',
#        'DewPointF_x', 'WindChillF_x', 'WindGustKmph_x', 'date_y', 'time_y',
#        'airport_y', 'tempF_y', 'windspeedKmph_y', 'winddirDegree_y',
#        'weatherCode_y', 'precipMM_y', 'humidity_y', 'visibility_y',
#        'pressure_y', 'cloudcover_y', 'DewPointF_y', 'WindChillF_y',
#        'WindGustKmph_y'],
#       dtype='object')

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-f9087a074d7a> in <module>
# ----> 1 type(df.data)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'data'

# %%
who
# Out:
# LogisticRegression	 accuracy_score	 classification_report	 df_majority	 df_minority	 df_new	 feature_name	 list_df	 pd
# pred	 train_test_split	 x	 x_test	 x_train	 y	 y_pred	 y_test	 y_train

# %%
del DecisionTreeClassifier

# %%
del RandomForestClassifier

# %%
del clf

# %%
del df

# %%
del list_df

# %%
import imblearn
